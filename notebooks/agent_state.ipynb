# %%
from langchain_openai import ChatOpenAI
from pydantic.v1 import BaseModel
from typing import *
from langchain_core.messages import BaseMessage

# %%
class AgentState(BaseModel):
    name: str
    age: str
    location: Optional[str] = None

# %%
# function 
class AgentState(TypedDict):
    messages: List[BaseMessage]
    x: str

# %%
llm = ChatOpenAI()

def chatbot(state: AgentState):
    message = state["messages"]
    print("state", state)
    print("message", message)
    
    output = llm.invoke(message)
    # return output.content
    y =  state["messages"] + output.content
    print("y", y)

# %%
chatbot({"messages": "who are developed you ", "x": "Goldy"})
# Out:
# state {'messages': 'who are developed you ', 'x': 'Goldy'}
# message who are developed you
# y who are developed you I am an AI developed by a team of engineers and researchers at OpenAI.

# %%
chatbot("hello how are you? ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 chatbot("hello how are you? ")
#
# Cell In[19], line 4, in chatbot(state)
#       3 def chatbot(state: AgentState):
# ----> 4     message = state["messages"][-1]
#       5     print(message)
#       7     output = llm.invoke(message)
#
# TypeError: string indices must be integers, not 'str'
